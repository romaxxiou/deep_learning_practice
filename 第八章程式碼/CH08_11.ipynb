# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
# 匯入Keras的mnist模組
from tensorflow.keras.datasets import mnist
(train_Data, train_Label), (test_Data, test_Label) = mnist.load_data()

model = Sequential([
    layers.Flatten(input_shape=(28, 28)),   # 將輸入資料從 28x28 攤平成 784
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax') # output 為 10 個 class
])

# model 每層定義好後需要經過 compile
# sparse_categorical_crossentropy 的標籤是 integer
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

from tensorflow.keras.callbacks import ModelCheckpoint

model_checkpoint = ModelCheckpoint(filepath='weights.{epoch:02d}-{val_accuracy:.4f}.h5',
                                  monitor='val_accuracy',save_best_only=True,verbose=1)

# 將建立好的 model 去 fit 我們的 training data
history = model.fit(train_Data, train_Label, 
                    epochs=20, batch_size=512,
                    validation_split=0.2,verbose=2,
                    callbacks=[model_checkpoint])  # 添加 callback
# 利用 test_Data 去進行模型評估
# verbose = 2 為每個 epoch 輸出一行紀錄
model.evaluate(test_Data, test_Label, verbose=2)
# Out:
# Epoch 1/20
# 94/94 - 1s - loss: 4.3794 - accuracy: 0.7862 - val_loss: 0.7750 - val_accuracy: 0.8914
#
# Epoch 00001: val_accuracy improved from -inf to 0.89142, saving model to weights.01-0.8914.h5
# Epoch 2/20
# 94/94 - 0s - loss: 0.5311 - accuracy: 0.9090 - val_loss: 0.5125 - val_accuracy: 0.9146
#
# Epoch 00002: val_accuracy improved from 0.89142 to 0.91458, saving model to weights.02-0.9146.h5
# Epoch 3/20
# 94/94 - 0s - loss: 0.3094 - accuracy: 0.9344 - val_loss: 0.4041 - val_accuracy: 0.9290
#
# Epoch 00003: val_accuracy improved from 0.91458 to 0.92900, saving model to weights.03-0.9290.h5
# Epoch 4/20
# 94/94 - 0s - loss: 0.1965 - accuracy: 0.9525 - val_loss: 0.3591 - val_accuracy: 0.9327
#
# Epoch 00004: val_accuracy improved from 0.92900 to 0.93275, saving model to weights.04-0.9327.h5
# Epoch 5/20
# 94/94 - 0s - loss: 0.1364 - accuracy: 0.9640 - val_loss: 0.3318 - val_accuracy: 0.9367
#
# Epoch 00005: val_accuracy improved from 0.93275 to 0.93667, saving model to weights.05-0.9367.h5
# Epoch 6/20
# 94/94 - 0s - loss: 0.0972 - accuracy: 0.9727 - val_loss: 0.3201 - val_accuracy: 0.9409
#
# Epoch 00006: val_accuracy improved from 0.93667 to 0.94092, saving model to weights.06-0.9409.h5
# Epoch 7/20
# 94/94 - 0s - loss: 0.0736 - accuracy: 0.9775 - val_loss: 0.3135 - val_accuracy: 0.9426
#
# Epoch 00007: val_accuracy improved from 0.94092 to 0.94258, saving model to weights.07-0.9426.h5
# Epoch 8/20
# 94/94 - 0s - loss: 0.0514 - accuracy: 0.9846 - val_loss: 0.3108 - val_accuracy: 0.9433
#
# Epoch 00008: val_accuracy improved from 0.94258 to 0.94325, saving model to weights.08-0.9433.h5
# Epoch 9/20
# 94/94 - 0s - loss: 0.0416 - accuracy: 0.9868 - val_loss: 0.2988 - val_accuracy: 0.9470
#
# Epoch 00009: val_accuracy improved from 0.94325 to 0.94700, saving model to weights.09-0.9470.h5
# Epoch 10/20
# 94/94 - 0s - loss: 0.0287 - accuracy: 0.9912 - val_loss: 0.3022 - val_accuracy: 0.9486
#
# Epoch 00010: val_accuracy improved from 0.94700 to 0.94858, saving model to weights.10-0.9486.h5
# Epoch 11/20
# 94/94 - 0s - loss: 0.0211 - accuracy: 0.9940 - val_loss: 0.2870 - val_accuracy: 0.9518
#
# Epoch 00011: val_accuracy improved from 0.94858 to 0.95183, saving model to weights.11-0.9518.h5
# Epoch 12/20
# 94/94 - 0s - loss: 0.0149 - accuracy: 0.9960 - val_loss: 0.3067 - val_accuracy: 0.9511
#
# Epoch 00012: val_accuracy did not improve from 0.95183
# Epoch 13/20
# 94/94 - 0s - loss: 0.0135 - accuracy: 0.9964 - val_loss: 0.2874 - val_accuracy: 0.9539
#
# Epoch 00013: val_accuracy improved from 0.95183 to 0.95392, saving model to weights.13-0.9539.h5
# Epoch 14/20
# 94/94 - 0s - loss: 0.0084 - accuracy: 0.9982 - val_loss: 0.2984 - val_accuracy: 0.9530
#
# Epoch 00014: val_accuracy did not improve from 0.95392
# Epoch 15/20
# 94/94 - 0s - loss: 0.0060 - accuracy: 0.9991 - val_loss: 0.3047 - val_accuracy: 0.9521
#
# Epoch 00015: val_accuracy did not improve from 0.95392
# Epoch 16/20
# 94/94 - 0s - loss: 0.0042 - accuracy: 0.9994 - val_loss: 0.3025 - val_accuracy: 0.9559
#
# Epoch 00016: val_accuracy improved from 0.95392 to 0.95592, saving model to weights.16-0.9559.h5
# Epoch 17/20
# 94/94 - 0s - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.3004 - val_accuracy: 0.9563
#
# Epoch 00017: val_accuracy improved from 0.95592 to 0.95625, saving model to weights.17-0.9563.h5
# Epoch 18/20
# 94/94 - 0s - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.3030 - val_accuracy: 0.9563
#
# Epoch 00018: val_accuracy improved from 0.95625 to 0.95633, saving model to weights.18-0.9563.h5
# Epoch 19/20
# 94/94 - 0s - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.3088 - val_accuracy: 0.9555
#
# Epoch 00019: val_accuracy did not improve from 0.95633
# Epoch 20/20
# 94/94 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3063 - val_accuracy: 0.9570
#
# Epoch 00020: val_accuracy improved from 0.95633 to 0.95700, saving model to weights.20-0.9570.h5
# 313/313 - 0s - loss: 0.3029 - accuracy: 0.9533
# [0.3029274046421051, 0.9532999992370605]
